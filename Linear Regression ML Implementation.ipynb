# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Lets load the Boston House Pricing Dataset

# %%
boston=pd.read_csv("final.csv")

# %%
boston.keys()
# Out:
# Index(['HoleDiameter', 'HoleDepth', 'BurdenSpacingRatio', 'Stemming',
#        'MaxChargePerDelay', 'PowderFactor', 'FlyrockDistance'],
#       dtype='object')

# %%
## Lets check the description of the dataset
print(boston.HoleDiameter)
# Out:
# 0       75
# 1       75
# 2       75
# 3       75
# 4       75
#       ...
# 257    150
# 258    150
# 259    150
# 260    150
# 261    150
# Name: HoleDiameter, Length: 262, dtype: int64

# %%
print(boston.FlyrockDistance)
# Out:
# 0       75.0
# 1       80.0
# 2       84.0
# 3       90.0
# 4       67.0
#        ...
# 257    270.0
# 258    320.0
# 259    290.0
# 260    300.0
# 261    350.0
# Name: FlyrockDistance, Length: 262, dtype: float64

# %% [markdown]
# ## Preparing The Dataset

# %%
dataset = pd.read_csv("final.csv")

# %%
dataset.head()
# Out:
#    HoleDiameter  HoleDepth  BurdenSpacingRatio  Stemming  MaxChargePerDelay  \
# 0            75       10.0                0.40       1.8          47.712928
# 1            75       10.0                0.40       1.8          47.712928
# 2            75       10.0                0.44       2.0          47.712928
# 3            75       11.0                0.42       2.0          53.014365
# 4            75       11.0                0.42       1.4          53.014365
#
#    PowderFactor  FlyrockDistance
# 0          0.50             75.0
# 1          0.60             80.0
# 2          0.55             84.0
# 3          0.50             90.0
# 4          0.45             67.0

# %%
dataset.head()
# Out:
#    HoleDiameter  HoleDepth  BurdenSpacingRatio  Stemming  MaxChargePerDelay  \
# 0            75       10.0                0.40       1.8          47.712928
# 1            75       10.0                0.40       1.8          47.712928
# 2            75       10.0                0.44       2.0          47.712928
# 3            75       11.0                0.42       2.0          53.014365
# 4            75       11.0                0.42       1.4          53.014365
#
#    PowderFactor  FlyrockDistance
# 0          0.50             75.0
# 1          0.60             80.0
# 2          0.55             84.0
# 3          0.50             90.0
# 4          0.45             67.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   HoleDiameter        262 non-null    int64
#  1   HoleDepth           262 non-null    float64
#  2   BurdenSpacingRatio  262 non-null    float64
#  3   Stemming            262 non-null    float64
#  4   MaxChargePerDelay   262 non-null    float64
#  5   PowderFactor        262 non-null    float64
#  6   FlyrockDistance     262 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 14.5 KB

# %%
## Summarizing The Stats of the data
dataset.describe()
# Out:
#        HoleDiameter   HoleDepth  BurdenSpacingRatio    Stemming  \
# count    262.000000  262.000000          262.000000  262.000000
# mean     115.812977   19.755725            0.702082    2.975382
# std       28.203817    5.654777            0.144514    0.770564
# min       75.000000   10.000000            0.400000    1.400000
# 25%       89.000000   15.000000            0.532635    2.500000
# 50%      115.000000   20.000000            0.750000    3.000000
# 75%      150.000000   24.750000            0.827679    3.575000
# max      150.000000   29.000000            0.950000    4.500000
#
#        MaxChargePerDelay  PowderFactor  FlyrockDistance
# count         262.000000    262.000000       262.000000
# mean          257.634125      0.784695       204.580153
# std           152.892724      0.162343        64.286246
# min            47.712928      0.450000        67.000000
# 25%           126.911206      0.650000       157.000000
# ...

# %%
## Check the missing Values
dataset.isnull().sum()
# Out:
# HoleDiameter          0
# HoleDepth             0
# BurdenSpacingRatio    0
# Stemming              0
# MaxChargePerDelay     0
# PowderFactor          0
# FlyrockDistance       0
# dtype: int64

# %%
### EXploratory Data Analysis
## Correlation
dataset.corr()
# Out:
#                     HoleDiameter  HoleDepth  BurdenSpacingRatio  Stemming  \
# HoleDiameter            1.000000   0.183492            0.530164  0.624078
# HoleDepth               0.183492   1.000000            0.187772  0.398738
# BurdenSpacingRatio      0.530164   0.187772            1.000000  0.388833
# Stemming                0.624078   0.398738            0.388833  1.000000
# MaxChargePerDelay       0.868781   0.592194            0.489359  0.650006
# PowderFactor            0.384531   0.179633            0.373170  0.331326
# FlyrockDistance         0.790382   0.443531            0.563910  0.590885
#
#                     MaxChargePerDelay  PowderFactor  FlyrockDistance
# HoleDiameter                 0.868781      0.384531         0.790382
# HoleDepth                    0.592194      0.179633         0.443531
# BurdenSpacingRatio           0.489359      0.373170         0.563910
# Stemming                     0.650006      0.331326         0.590885
# ...

# %%
import seaborn as sns
sns.pairplot(dataset)

# %% [markdown]
# ## Analyzing The Correlated Features

# %%
dataset.corr()
# Out:
#                     HoleDiameter  HoleDepth  BurdenSpacingRatio  Stemming  \
# HoleDiameter            1.000000   0.183492            0.530164  0.624078
# HoleDepth               0.183492   1.000000            0.187772  0.398738
# BurdenSpacingRatio      0.530164   0.187772            1.000000  0.388833
# Stemming                0.624078   0.398738            0.388833  1.000000
# MaxChargePerDelay       0.868781   0.592194            0.489359  0.650006
# PowderFactor            0.384531   0.179633            0.373170  0.331326
# FlyrockDistance         0.790382   0.443531            0.563910  0.590885
#
#                     MaxChargePerDelay  PowderFactor  FlyrockDistance
# HoleDiameter                 0.868781      0.384531         0.790382
# HoleDepth                    0.592194      0.179633         0.443531
# BurdenSpacingRatio           0.489359      0.373170         0.563910
# Stemming                     0.650006      0.331326         0.590885
# ...

# %%
plt.scatter(dataset['HoleDiameter'],dataset['FlyrockDistance'])
plt.xlabel("HoleDiameter")
plt.ylabel("FlyrockDistance")
# Out:
# Text(0, 0.5, 'FlyrockDistance')

# %%
plt.scatter(dataset['HoleDepth'],dataset['FlyrockDistance'])
plt.xlabel("HoleDepth")
plt.ylabel("FlyrockDistance")
# Out:
# Text(0, 0.5, 'FlyrockDistance')

# %%
import seaborn as sns
sns.regplot(x="HoleDepth",y="FlyrockDistance",data=dataset)
# Out:
# <Axes: xlabel='HoleDepth', ylabel='FlyrockDistance'>

# %%
sns.regplot(x="BurdenSpacingRatio",y="FlyrockDistance",data=dataset)
# Out:
# <Axes: xlabel='BurdenSpacingRatio', ylabel='FlyrockDistance'>

# %%
sns.regplot(x="Stemming",y="FlyrockDistance",data=dataset)
# Out:
# <Axes: xlabel='Stemming', ylabel='FlyrockDistance'>

# %%
sns.regplot(x="MaxChargePerDelay",y="FlyrockDistance",data=dataset)
# Out:
# <Axes: xlabel='MaxChargePerDelay', ylabel='FlyrockDistance'>

# %%
## Independent and Dependent features

X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
X.head()
# Out:
#    HoleDiameter  HoleDepth  BurdenSpacingRatio  Stemming  MaxChargePerDelay  \
# 0            75       10.0                0.40       1.8          47.712928
# 1            75       10.0                0.40       1.8          47.712928
# 2            75       10.0                0.44       2.0          47.712928
# 3            75       11.0                0.42       2.0          53.014365
# 4            75       11.0                0.42       1.4          53.014365
#
#    PowderFactor
# 0          0.50
# 1          0.60
# 2          0.55
# 3          0.50
# 4          0.45

# %%
y
# Out:
# 0       75.0
# 1       80.0
# 2       84.0
# 3       90.0
# 4       67.0
#        ...
# 257    270.0
# 258    320.0
# 259    290.0
# 260    300.0
# 261    350.0
# Name: FlyrockDistance, Length: 262, dtype: float64

# %%
##Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#      HoleDiameter  HoleDepth  BurdenSpacingRatio  Stemming  MaxChargePerDelay  \
# 119           115       16.0            0.690000       3.2         186.963994
# 143           115       24.0            0.520000       3.5         286.678124
# 69             89       23.0            0.689655       2.0         164.238032
# 2              75       10.0            0.440000       2.0          47.712928
# 124           115       18.0            0.490000       3.7         211.892526
# ..            ...        ...                 ...       ...                ...
# 20             75       20.0            0.410256       1.7         100.727294
# 188           150       18.0            0.857143       3.7         360.497682
# 71             89       24.0            0.560000       2.9         171.703397
# 106           115       11.0            0.520000       2.3         124.642663
# 102           115       11.0            0.520000       2.0         124.642663
#
#      PowderFactor
# ...

# %%
X_test
# Out:
#      HoleDiameter  HoleDepth  BurdenSpacingRatio  Stemming  MaxChargePerDelay  \
# 248           150       15.5            0.882353       4.2         307.483317
# 215           150       29.0            0.863636       3.4         550.000000
# 194           150       20.0            0.800000       3.7         402.909174
# 168           115       13.0            0.857143       3.5         149.571195
# 66             89       22.0            0.510000       3.0         156.772666
# ..            ...        ...                 ...       ...                ...
# 92             89       28.0            0.520000       2.9         201.564857
# 125           115       18.0            0.825000       3.5         211.892526
# 152           115       27.0            0.690000       2.7         324.070923
# 84             89       27.0            0.756757       2.6         194.099492
# 239           150       25.0            0.882353       2.5         508.937904
#
#      PowderFactor
# ...

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[-0.03419328, -0.60497934, -0.08601796,  0.24852803, -0.44841664,
#          0.39482172],
#        [-0.03419328,  0.77783058, -1.26640841,  0.62336839,  0.18765231,
#          0.09773136],
#        [-0.95857747,  0.60497934, -0.08841226, -1.2508334 , -0.59338385,
#          1.28609278],
#        ...,
#        [-0.95857747,  0.77783058, -0.98866948, -0.12631233, -0.54576284,
#          0.09773136],
#        [-0.03419328, -1.46923554, -1.26640841, -0.87599304, -0.84595973,
#          0.69191207],
#        [-0.03419328, -1.46923554, -1.26640841, -1.2508334 , -0.84595973,
#          0.39482172]])

# %%
X_test
# Out:
# array([[ 1.21017005e+00, -6.91404958e-01,  1.24957954e+00,
#          1.49799590e+00,  3.20367069e-01,  5.73075931e-01],
#        [ 1.21017005e+00,  1.64208678e+00,  1.11962148e+00,
#          4.98421608e-01,  1.86736277e+00,  9.77313628e-02],
#        [ 1.21017005e+00,  8.64256198e-02,  6.77764096e-01,
#          8.73261967e-01,  9.29081442e-01,  6.91912074e-01],
#        [-3.41932780e-02, -1.12353306e+00,  1.07453400e+00,
#          6.23368394e-01, -6.86942493e-01,  3.94821718e-01],
#        [-9.58577465e-01,  4.32128099e-01, -1.33584315e+00,
#         -1.36553865e-03, -6.41004848e-01, -1.09063006e+00],
#        [-3.41932780e-02,  4.32128099e-01, -1.40527788e+00,
#          7.48315181e-01,  2.86350697e-02, -4.96449348e-01],
#        [ 1.21017005e+00, -7.77830578e-01,  6.77764096e-01,
#         -1.26312325e-01,  2.52732139e-01,  9.77313628e-02],
#        [ 1.21017005e+00,  1.46923554e+00,  1.71928508e+00,
#          1.12315554e+00,  2.01124033e+00,  2.16567505e-01],
# ...

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and the intercept
print(regression.coef_)
# Out:
# [14.78800287  6.49573787  7.37843954 -0.6675987  28.42073776 19.43417063]

# %%
print(regression.intercept_)
# Out:
# 204.18306010928958

# %%
## on which parameters the model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
### Prediction With Test Data
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([246.05008379, 295.64509294, 266.91022663, 192.04107797,
#        143.54575705, 186.78181704, 231.19380391, 304.92839481,
#        105.89238308, 147.11188732, 117.15827864, 285.8212518 ,
#        148.89269766, 289.63500792, 247.50554161, 286.3875847 ,
#        217.04300874,  92.28385976, 285.39799433, 152.37958227,
#        211.06810425, 211.7257222 , 132.95059348, 268.59562466,
#        175.25832551, 233.55774648, 184.57491873, 180.58079108,
#        171.29695174, 131.28725611, 168.57453356, 247.02537307,
#        274.85232486, 184.41621059, 145.48166807, 240.76603413,
#        185.95226858, 313.25263872, 274.12892708, 113.5512018 ,
#        272.44712119, 116.3841882 , 192.28751599, 149.43549308,
#        158.15170803, 223.56032718, 311.49842652, 138.49676866,
#        193.65476914, 211.7257222 , 270.30983783, 191.15124402,
#        216.47975756, 265.50143497, 173.6726102 , 153.82442564,
#        279.73025289, 133.14143478, 140.28077348, 158.52400561,
# ...

# %% [markdown]
# ## Assumptions

# %%
## plot a scatter plot for the prediction
plt.scatter(y_test,reg_pred)

# %%
## Residuals
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 248    53.949916
# 215   -20.645093
# 194    33.089773
# 168   -12.041078
# 66     13.454243
#          ...
# 92     -3.225109
# 125   -32.254194
# 152   -36.631666
# 84     -1.997176
# 239   -36.573964
# Name: FlyrockDistance, Length: 79, dtype: float64

# %%
## Plot this residuals 

sns.displot(residuals,kind="kde")

# %%
## Scatter plot with respect to prediction and residuals
## uniform distribution
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 19.259953586713067
# 606.5257311129561
# 24.627743118543286

# %% [markdown]
# ## R square and adjusted R square

# %% [markdown]
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.8364365068772588

# %% [markdown]
# **Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]**
#
# where:
#
# R2: The R2 of the model
# n: The number of observations
# k: The number of predictor variables

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.8228062157836971

# %% [markdown]
# ## New Data Prediction

# %%
boston.BurdenSpacingRatio[0].reshape(1,-1)
# Out:
# array([[0.4]])

# %%
##transformation of new data
scaler.transform(boston.BurdenSpacingRatio[0].reshape(1,-1))
# Out:
# C:\Users\atula\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 2
#       1 ##transformation of new data
# ----> 2 scaler.transform(boston.BurdenSpacingRatio[0].reshape(1,-1))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
# ...

# %%
regression.predict(scaler.transform(boston.HoleDiameter[0].reshape(1,-1)))
# Out:
# C:\Users\atula\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 regression.predict(scaler.transform(boston.HoleDiameter[0].reshape(1,-1)))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
# ...

# %% [markdown]
# ## Pickling The Model file For Deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
## Prediction
pickled_model.predict(scaler.transform(boston.BurdenSpacingRatio[0].reshape(1,-1)))
# Out:
# C:\Users\atula\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 2
#       1 ## Prediction
# ----> 2 pickled_model.predict(scaler.transform(boston.BurdenSpacingRatio[0].reshape(1,-1)))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
# ...
